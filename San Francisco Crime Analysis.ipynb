# %% [markdown]
# # San Francisco Crime Analysis

# %% [markdown]
# In this project, 15-year crime data from SFPD was analyzed. Data processing pipeline was initialized based on Spark RDD, Dataframe and Spark SQL for big data OLAP.

# %% [markdown]
# <ul>
# <li>[Part 1: Data Exploration](#Part-1:-Data-Exploration)
# <li>[Part 2: Bid Data OLAP](#Part-2:-Bid Data OLAP)
# <li>[Part 3: Counts the number of crimes for different category](#Part-3:-Counts the number of crimes for different category)
# <li>[Part 4: Count the number of crimes for different district](#Part-4:-Count the number of crimes for different district)
# <li>[Part 5: Count the number of crimes each Sunday at SF downtown](#Part-5:-UCount the number of crimes each Sunday at SF downtown)
# <li>[Part 6: Visualize the spatial distribution of crimes and run a kmeans clustering algorithm](#Part-5:-Visualize the spatial distribution of crimes and run a kmeans clustering algorithm)
# </ul>

# %% [markdown]
# # Part 1: Data Exploration

# %%
#import the data reader
from csv import reader
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#read data from the data storage
crime_data_lines = sc.textFile('/FileStore/tables/sf_data.csv')
#prepare data 
df_crimes = crime_data_lines.map(lambda line: [x.strip('"') for x in next(reader([line]))])
#get header
header = df_crimes.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
header
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">69</span><span class="ansired">]: </span>
# [&apos;IncidntNum&apos;,
#  &apos;Category&apos;,
#  &apos;Descript&apos;,
#  &apos;DayOfWeek&apos;,
#  &apos;Date&apos;,
#  &apos;Time&apos;,
#  &apos;PdDistrict&apos;,
#  &apos;Resolution&apos;,
#  &apos;Address&apos;,
#  &apos;X&apos;,
#  &apos;Y&apos;,
#  &apos;Location&apos;,
#  &apos;PdId&apos;]
# </div>

# %%
#remove the first line of data
crimes = df_crimes.filter(lambda x: x != header)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PythonRDD[387] at RDD at PythonRDD.scala:50
# </div>

# %%
#get the first line of data
display(crimes.take(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th><th>_3</th><th>_4</th><th>_5</th><th>_6</th><th>_7</th><th>_8</th><th>_9</th><th>_10</th><th>_11</th><th>_12</th><th>_13</th></tr></thead><tbody><tr><td>176184067</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:15</td><td>SOUTHERN</td><td>NONE</td><td>SHIPLEY ST / 4TH ST</td><td>-122.40061739890338</td><td>37.7815876234701</td><td>(37.7815876234701, -122.40061739890338)</td><td>17618406706244</td></tr><tr><td>176183906</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>09:45</td><td>PARK</td><td>NONE</td><td>HAYES ST / SCOTT ST</td><td>-122.43613031282463</td><td>37.775205514978545</td><td>(37.775205514978545, -122.43613031282463)</td><td>17618390606244</td></tr></tbody></table></div>

# %% [markdown]
# # Part 2: Big data OLAP
# ####  approach 1: use RDD
# #### approach 2: use Dataframe, register the RDD to a dataframe
# #### approach 3: use SQL

# %% [markdown]
# ## 2.1 Use RDD

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("crime analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

df_opt1 = spark.read.format("csv").option("header", "true").load("/FileStore/tables/sf_data.csv")
display(df_opt1)
df_opt1.createOrReplaceTempView("sf_crime")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IncidntNum</th><th>Category</th><th>Descript</th><th>DayOfWeek</th><th>Date</th><th>Time</th><th>PdDistrict</th><th>Resolution</th><th>Address</th><th>X</th><th>Y</th><th>Location</th><th>PdId</th></tr></thead><tbody><tr><td>176184067</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:15</td><td>SOUTHERN</td><td>NONE</td><td>SHIPLEY ST / 4TH ST</td><td>-122.40061739890338</td><td>37.7815876234701</td><td>(37.7815876234701, -122.40061739890338)</td><td>17618406706244</td></tr><tr><td>176183906</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>09:45</td><td>PARK</td><td>NONE</td><td>HAYES ST / SCOTT ST</td><td>-122.43613031282463</td><td>37.775205514978545</td><td>(37.775205514978545, -122.43613031282463)</td><td>17618390606244</td></tr><tr><td>176183423</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>10:50</td><td>TARAVAL</td><td>NONE</td><td>KIRKHAM ST / LA PLAYA ST</td><td>-122.50910925205717</td><td>37.75841171643452</td><td>(37.75841171643452, -122.50910925205717)</td><td>17618342306244</td></tr><tr><td>176182776</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:00</td><td>RICHMOND</td><td>NONE</td><td>100 Block of LAKE ST</td><td>-122.46095180410846</td><td>37.78689526736518</td><td>(37.78689526736518, -122.46095180410846)</td><td>17618277606244</td></tr><tr><td>176182754</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>07:15</td><td>RICHMOND</td><td>NONE</td><td>POINTLOBOS AV / 48TH AV</td><td>-122.50943307434102</td><td>37.779849075879056</td><td>(37.779849075879056, -122.50943307434102)</td><td>17618275406244</td></tr><tr><td>176182538</td><td>LARCENY/THEFT</td><td>PETTY THEFT OF PROPERTY</td><td>Tuesday</td><td>07/11/2017</td><td>10:00</td><td>PARK</td><td>NONE</td><td>2200 Block of HAYES ST</td><td>-122.4534813455352</td><td>37.773052871338244</td><td>(37.773052871338244, -122.4534813455352)</td><td>17618253806372</td></tr><tr><td>176182522</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>12:00</td><td>RICHMOND</td><td>NONE</td><td>500 Block of JOHNFKENNEDY DR</td><td>-122.46620466789287</td><td>37.772540539159316</td><td>(37.772540539159316, -122.46620466789287)</td><td>17618252206244</td></tr><tr><td>176181778</td><td>BURGLARY</td><td>BURGLARY, UNLAWFUL ENTRY</td><td>Tuesday</td><td>07/11/2017</td><td>14:43</td><td>TARAVAL</td><td>NONE</td><td>1800 Block of 10TH AV</td><td>-122.4667330308776</td><td>37.753714592060966</td><td>(37.753714592060966, -122.4667330308776)</td><td>17618177805073</td></tr><tr><td>176181762</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:45</td><td>TARAVAL</td><td>NONE</td><td>17TH AV / TARAVAL ST</td><td>-122.4735538773959</td><td>37.74314326922748</td><td>(37.74314326922748, -122.4735538773959)</td><td>17618176206244</td></tr><tr><td>176181665</td><td>LARCENY/THEFT</td><td>PETTY THEFT OF PROPERTY</td><td>Tuesday</td><td>07/11/2017</td><td>20:44</td><td>SOUTHERN</td><td>NONE</td><td>800 Block of BRYANT ST</td><td>-122.40340479147905</td><td>37.775420706711</td><td>(37.775420706711, -122.40340479147905)</td><td>17618166506372</td></tr><tr><td>176181659</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>11:15</td><td>TARAVAL</td><td>NONE</td><td>34TH AV / LINCOLN WY</td><td>-122.49332835851789</td><td>37.76473124436024</td><td>(37.76473124436024, -122.49332835851789)</td><td>17618165906244</td></tr><tr><td>176181637</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>12:55</td><td>TARAVAL</td><td>NONE</td> ...

# %% [markdown]
# ## 2.2 Use Dataframe, register the RDD to a dataframe

# %%
from pyspark.sql import Row

def createRow(keys, values):
  assert len(keys) == len(values)
  mapped = dict(zip(keys, values))
  return Row(**mapped)

rdd_rows = crimes.map(lambda x: createRow(header, x))

df_opt2 = spark.createDataFrame(rdd_rows)
df_opt2.createOrReplaceTempView("sf_crime")
display(df_opt2.select(df_opt2.columns[6]).take(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Location</th></tr></thead><tbody><tr><td>(37.7815876234701, -122.40061739890338)</td></tr><tr><td>(37.775205514978545, -122.43613031282463)</td></tr><tr><td>(37.75841171643452, -122.50910925205717)</td></tr><tr><td>(37.78689526736518, -122.46095180410846)</td></tr><tr><td>(37.779849075879056, -122.50943307434102)</td></tr></tbody></table></div>

# %% [markdown]
# ## 2.3 Use SQL

# %%
df_opt3 = crimes.toDF(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId'])
display(df_opt3)
df_opt3.createOrReplaceTempView("sf_crime")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IncidntNum</th><th>Category</th><th>Descript</th><th>DayOfWeek</th><th>Date</th><th>Time</th><th>PdDistrict</th><th>Resolution</th><th>Address</th><th>X</th><th>Y</th><th>Location</th><th>PdId</th></tr></thead><tbody><tr><td>176184067</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:15</td><td>SOUTHERN</td><td>NONE</td><td>SHIPLEY ST / 4TH ST</td><td>-122.40061739890338</td><td>37.7815876234701</td><td>(37.7815876234701, -122.40061739890338)</td><td>17618406706244</td></tr><tr><td>176183906</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>09:45</td><td>PARK</td><td>NONE</td><td>HAYES ST / SCOTT ST</td><td>-122.43613031282463</td><td>37.775205514978545</td><td>(37.775205514978545, -122.43613031282463)</td><td>17618390606244</td></tr><tr><td>176183423</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>10:50</td><td>TARAVAL</td><td>NONE</td><td>KIRKHAM ST / LA PLAYA ST</td><td>-122.50910925205717</td><td>37.75841171643452</td><td>(37.75841171643452, -122.50910925205717)</td><td>17618342306244</td></tr><tr><td>176182776</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:00</td><td>RICHMOND</td><td>NONE</td><td>100 Block of LAKE ST</td><td>-122.46095180410846</td><td>37.78689526736518</td><td>(37.78689526736518, -122.46095180410846)</td><td>17618277606244</td></tr><tr><td>176182754</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>07:15</td><td>RICHMOND</td><td>NONE</td><td>POINTLOBOS AV / 48TH AV</td><td>-122.50943307434102</td><td>37.779849075879056</td><td>(37.779849075879056, -122.50943307434102)</td><td>17618275406244</td></tr><tr><td>176182538</td><td>LARCENY/THEFT</td><td>PETTY THEFT OF PROPERTY</td><td>Tuesday</td><td>07/11/2017</td><td>10:00</td><td>PARK</td><td>NONE</td><td>2200 Block of HAYES ST</td><td>-122.4534813455352</td><td>37.773052871338244</td><td>(37.773052871338244, -122.4534813455352)</td><td>17618253806372</td></tr><tr><td>176182522</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>12:00</td><td>RICHMOND</td><td>NONE</td><td>500 Block of JOHNFKENNEDY DR</td><td>-122.46620466789287</td><td>37.772540539159316</td><td>(37.772540539159316, -122.46620466789287)</td><td>17618252206244</td></tr><tr><td>176181778</td><td>BURGLARY</td><td>BURGLARY, UNLAWFUL ENTRY</td><td>Tuesday</td><td>07/11/2017</td><td>14:43</td><td>TARAVAL</td><td>NONE</td><td>1800 Block of 10TH AV</td><td>-122.4667330308776</td><td>37.753714592060966</td><td>(37.753714592060966, -122.4667330308776)</td><td>17618177805073</td></tr><tr><td>176181762</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>18:45</td><td>TARAVAL</td><td>NONE</td><td>17TH AV / TARAVAL ST</td><td>-122.4735538773959</td><td>37.74314326922748</td><td>(37.74314326922748, -122.4735538773959)</td><td>17618176206244</td></tr><tr><td>176181665</td><td>LARCENY/THEFT</td><td>PETTY THEFT OF PROPERTY</td><td>Tuesday</td><td>07/11/2017</td><td>20:44</td><td>SOUTHERN</td><td>NONE</td><td>800 Block of BRYANT ST</td><td>-122.40340479147905</td><td>37.775420706711</td><td>(37.775420706711, -122.40340479147905)</td><td>17618166506372</td></tr><tr><td>176181659</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>11:15</td><td>TARAVAL</td><td>NONE</td><td>34TH AV / LINCOLN WY</td><td>-122.49332835851789</td><td>37.76473124436024</td><td>(37.76473124436024, -122.49332835851789)</td><td>17618165906244</td></tr><tr><td>176181637</td><td>LARCENY/THEFT</td><td>GRAND THEFT FROM LOCKED AUTO</td><td>Tuesday</td><td>07/11/2017</td><td>12:55</td><td>TARAVAL</td><td>NONE</td> ...

# %% [markdown]
# # Part 3: Count the number of crimes for different category

# %% [markdown]
# ## Option1: rdd based

# %%
catorgory_set_rdd = crimes.map(lambda item: (item[1],1))
from operator import add
result = sorted(catorgory_set_rdd.reduceByKey(add).collect(), key = lambda item: -item[1])
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_1</th><th>_2</th></tr></thead><tbody><tr><td>LARCENY/THEFT</td><td>2805</td></tr><tr><td>OTHER OFFENSES</td><td>1002</td></tr><tr><td>NON-CRIMINAL</td><td>991</td></tr><tr><td>ASSAULT</td><td>780</td></tr><tr><td>VANDALISM</td><td>650</td></tr><tr><td>VEHICLE THEFT</td><td>353</td></tr><tr><td>WARRANTS</td><td>312</td></tr><tr><td>SUSPICIOUS OCC</td><td>312</td></tr><tr><td>BURGLARY</td><td>302</td></tr><tr><td>MISSING PERSON</td><td>265</td></tr><tr><td>ROBBERY</td><td>187</td></tr><tr><td>DRUG/NARCOTIC</td><td>167</td></tr><tr><td>FRAUD</td><td>155</td></tr><tr><td>SECONDARY CODES</td><td>118</td></tr><tr><td>TRESPASS</td><td>109</td></tr><tr><td>WEAPON LAWS</td><td>106</td></tr><tr><td>STOLEN PROPERTY</td><td>66</td></tr><tr><td>RECOVERED VEHICLE</td><td>48</td></tr><tr><td>SEX OFFENSES, FORCIBLE</td><td>40</td></tr><tr><td>RUNAWAY</td><td>39</td></tr><tr><td>ARSON</td><td>29</td></tr><tr><td>FORGERY/COUNTERFEITING</td><td>29</td></tr><tr><td>PROSTITUTION</td><td>20</td></tr><tr><td>DRUNKENNESS</td><td>19</td></tr><tr><td>DISORDERLY CONDUCT</td><td>18</td></tr><tr><td>DRIVING UNDER THE INFLUENCE</td><td>16</td></tr><tr><td>KIDNAPPING</td><td>10</td></tr><tr><td>BRIBERY</td><td>7</td></tr><tr><td>EMBEZZLEMENT</td><td>5</td></tr><tr><td>LOITERING</td><td>4</td></tr><tr><td>LIQUOR LAWS</td><td>4</td></tr><tr><td>SUICIDE</td><td>3</td></tr><tr><td>EXTORTION</td><td>2</td></tr><tr><td>TREA</td><td>1</td></tr><tr><td>PORNOGRAPHY/OBSCENE MAT</td><td>1</td></tr><tr><td>SEX OFFENSES, NON FORCIBLE</td><td>1</td></tr><tr><td>FAMILY OFFENSES</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Option2: Dataframe based

# %%
q1_result = df_opt1.groupBy('category').count().orderBy('count', ascending=False)
display(q1_result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>count</th></tr></thead><tbody><tr><td>LARCENY/THEFT</td><td>2805</td></tr><tr><td>OTHER OFFENSES</td><td>1002</td></tr><tr><td>NON-CRIMINAL</td><td>991</td></tr><tr><td>ASSAULT</td><td>780</td></tr><tr><td>VANDALISM</td><td>650</td></tr><tr><td>VEHICLE THEFT</td><td>353</td></tr><tr><td>SUSPICIOUS OCC</td><td>312</td></tr><tr><td>WARRANTS</td><td>312</td></tr><tr><td>BURGLARY</td><td>302</td></tr><tr><td>MISSING PERSON</td><td>265</td></tr><tr><td>ROBBERY</td><td>187</td></tr><tr><td>DRUG/NARCOTIC</td><td>167</td></tr><tr><td>FRAUD</td><td>155</td></tr><tr><td>SECONDARY CODES</td><td>118</td></tr><tr><td>TRESPASS</td><td>109</td></tr><tr><td>WEAPON LAWS</td><td>106</td></tr><tr><td>STOLEN PROPERTY</td><td>66</td></tr><tr><td>RECOVERED VEHICLE</td><td>48</td></tr><tr><td>SEX OFFENSES, FORCIBLE</td><td>40</td></tr><tr><td>RUNAWAY</td><td>39</td></tr><tr><td>FORGERY/COUNTERFEITING</td><td>29</td></tr><tr><td>ARSON</td><td>29</td></tr><tr><td>PROSTITUTION</td><td>20</td></tr><tr><td>DRUNKENNESS</td><td>19</td></tr><tr><td>DISORDERLY CONDUCT</td><td>18</td></tr><tr><td>DRIVING UNDER THE INFLUENCE</td><td>16</td></tr><tr><td>KIDNAPPING</td><td>10</td></tr><tr><td>BRIBERY</td><td>7</td></tr><tr><td>EMBEZZLEMENT</td><td>5</td></tr><tr><td>LIQUOR LAWS</td><td>4</td></tr><tr><td>LOITERING</td><td>4</td></tr><tr><td>SUICIDE</td><td>3</td></tr><tr><td>EXTORTION</td><td>2</td></tr><tr><td>FAMILY OFFENSES</td><td>1</td></tr><tr><td>SEX OFFENSES, NON FORCIBLE</td><td>1</td></tr><tr><td>TREA</td><td>1</td></tr><tr><td>PORNOGRAPHY/OBSCENE MAT</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Option3: Spark SQL based

# %%
crimeCategory = spark.sql("SELECT category, COUNT(*) AS Count FROM sf_crime GROUP BY category ORDER BY Count DESC")
display(crimeCategory)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>Count</th></tr></thead><tbody><tr><td>LARCENY/THEFT</td><td>2805</td></tr><tr><td>OTHER OFFENSES</td><td>1002</td></tr><tr><td>NON-CRIMINAL</td><td>991</td></tr><tr><td>ASSAULT</td><td>780</td></tr><tr><td>VANDALISM</td><td>650</td></tr><tr><td>VEHICLE THEFT</td><td>353</td></tr><tr><td>SUSPICIOUS OCC</td><td>312</td></tr><tr><td>WARRANTS</td><td>312</td></tr><tr><td>BURGLARY</td><td>302</td></tr><tr><td>MISSING PERSON</td><td>265</td></tr><tr><td>ROBBERY</td><td>187</td></tr><tr><td>DRUG/NARCOTIC</td><td>167</td></tr><tr><td>FRAUD</td><td>155</td></tr><tr><td>SECONDARY CODES</td><td>118</td></tr><tr><td>TRESPASS</td><td>109</td></tr><tr><td>WEAPON LAWS</td><td>106</td></tr><tr><td>STOLEN PROPERTY</td><td>66</td></tr><tr><td>RECOVERED VEHICLE</td><td>48</td></tr><tr><td>SEX OFFENSES, FORCIBLE</td><td>40</td></tr><tr><td>RUNAWAY</td><td>39</td></tr><tr><td>ARSON</td><td>29</td></tr><tr><td>FORGERY/COUNTERFEITING</td><td>29</td></tr><tr><td>PROSTITUTION</td><td>20</td></tr><tr><td>DRUNKENNESS</td><td>19</td></tr><tr><td>DISORDERLY CONDUCT</td><td>18</td></tr><tr><td>DRIVING UNDER THE INFLUENCE</td><td>16</td></tr><tr><td>KIDNAPPING</td><td>10</td></tr><tr><td>BRIBERY</td><td>7</td></tr><tr><td>EMBEZZLEMENT</td><td>5</td></tr><tr><td>LIQUOR LAWS</td><td>4</td></tr><tr><td>LOITERING</td><td>4</td></tr><tr><td>SUICIDE</td><td>3</td></tr><tr><td>EXTORTION</td><td>2</td></tr><tr><td>FAMILY OFFENSES</td><td>1</td></tr><tr><td>TREA</td><td>1</td></tr><tr><td>PORNOGRAPHY/OBSCENE MAT</td><td>1</td></tr><tr><td>SEX OFFENSES, NON FORCIBLE</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# # Part 4: Count the number of crimes for different district

# %%
#rdd based
district_rdd = crimes.map(lambda item: (item[6],1))
from operator import add
q2_result = sorted(district_rdd.reduceByKey(add).collect(), key = lambda item: -item[1])
# display(q2_result)
print crimes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PythonRDD[368] at RDD at PythonRDD.scala:50
# </div>

# %% [markdown]
# # Part 5: Count the number of crimes each Sunday at SF downtown.

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install shapely
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install matplotlib

import numpy as np
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
#Geo boundry of downtown San Francisco, data from https://data.sfgov.org/Geographic-Locations-and-Boundaries/Planning-Neighborhood-Groups-Map/iacs-ws63
downtown_lats_vect= [(-122.40238040199989, 37.79096861000005), (-122.40196043399993, 37.788922170000035), (-122.40206572999995, 37.78872115200005), (-122.40583101099992, 37.785743988000036), (-122.40895215899991, 37.78328785200006), (-122.40914170999991, 37.78351908500008), (-122.41043324499992, 37.78995142300005), (-122.40238040199989, 37.79096861000005)]
polygon = Polygon(downtown_lats_vect) # create polygon
sunday_rdd = crimes.filter(lambda x: x[3]=='Sunday') # filter out crimes happened on Sunday
Locations = sunday_rdd.map(lambda p: [float(p[9]),float(p[10]),p[4]]).collect()
# display(Locations)
count = {}
for Location in Locations:
    point = Point(Location[0],Location[1])
    # check if polygon contains point or a point is in the polygon
    if point.within(polygon) or polygon.contains(point):
      if Location[2] in count:
        count[Location[2]] +=1
      else:
        count[Location[2]] =1


print 'Crimes each Sunday at SF downtown: ',count
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Crimes each Sunday at SF downtown:  {&apos;07/23/2017&apos;: 16, &apos;07/30/2017&apos;: 16, &apos;07/16/2017&apos;: 18}
# </div>

# %%
#Visualize the results
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(range(len(count)), count.values(), align='center')
ax.set(xticks=range(len(count)), xticklabels=list(count.keys()))

display(fig)

# %% [markdown]
# # Part 6:  Visualize the spatial distribution of crimes and run a kmeans clustering algorithm

# %%
from pyspark.sql.types import FloatType
#In this part, we want to study the spatial distribution of crimes in SF
#Since kmeans groups objects solely on euclidean distance, it will be a good choice cluster the geo locations
crimes_x_y = spark.sql("SELECT X, Y FROM sf_crime WHERE X IS NOT NULL AND Y IS NOT NULL")
#change data type from string to float
crimes_x_y = crimes_x_y.withColumn("X", crimes_x_y["X"].cast(FloatType()))
crimes_x_y = crimes_x_y.withColumn("Y", crimes_x_y["Y"].cast(FloatType()))
display(crimes_x_y)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>X</th><th>Y</th></tr></thead><tbody><tr><td>-122.40062</td><td>37.78159</td></tr><tr><td>-122.43613</td><td>37.775204</td></tr><tr><td>-122.50911</td><td>37.75841</td></tr><tr><td>-122.46095</td><td>37.786896</td></tr><tr><td>-122.50943</td><td>37.77985</td></tr><tr><td>-122.45348</td><td>37.773052</td></tr><tr><td>-122.4662</td><td>37.77254</td></tr><tr><td>-122.466736</td><td>37.753716</td></tr><tr><td>-122.47356</td><td>37.743145</td></tr><tr><td>-122.403404</td><td>37.77542</td></tr><tr><td>-122.49333</td><td>37.764732</td></tr><tr><td>-122.47337</td><td>37.754944</td></tr><tr><td>-122.42615</td><td>37.73088</td></tr><tr><td>-122.40397</td><td>37.78483</td></tr><tr><td>-122.45918</td><td>37.728397</td></tr><tr><td>-122.417755</td><td>37.80611</td></tr><tr><td>-122.42037</td><td>37.7848</td></tr><tr><td>-122.39806</td><td>37.779568</td></tr><tr><td>-122.41474</td><td>37.77872</td></tr><tr><td>-122.38849</td><td>37.789574</td></tr><tr><td>-122.400925</td><td>37.78976</td></tr><tr><td>-122.41811</td><td>37.80702</td></tr><tr><td>-122.41246</td><td>37.79163</td></tr><tr><td>-122.41951</td><td>37.77637</td></tr><tr><td>-122.431366</td><td>37.785374</td></tr><tr><td>-122.403404</td><td>37.77542</td></tr><tr><td>-122.39741</td><td>37.780006</td></tr><tr><td>-122.39109</td><td>37.769176</td></tr><tr><td>-122.40019</td><td>37.790054</td></tr><tr><td>-122.398865</td><td>37.80078</td></tr><tr><td>-122.406</td><td>37.78854</td></tr><tr><td>-122.417046</td><td>37.789597</td></tr><tr><td>-122.407906</td><td>37.79406</td></tr><tr><td>-122.39872</td><td>37.799374</td></tr><tr><td>-122.40025</td><td>37.800606</td></tr><tr><td>-122.41008</td><td>37.796494</td></tr><tr><td>-122.41759</td><td>37.80034</td></tr><tr><td>-122.409805</td><td>37.790928</td></tr><tr><td>-122.42322</td><td>37.786404</td></tr><tr><td>-122.43426</td><td>37.77837</td></tr><tr><td>-122.40979</td><td>37.798508</td></tr><tr><td>-122.42469</td><td>37.785336</td></tr><tr><td>-122.41949</td><td>37.78875</td></tr><tr><td>-122.43322</td><td>37.77749</td></tr><tr><td>-122.44268</td><td>37.799507</td></tr><tr><td>-122.425186</td><td>37.800255</td></tr><tr><td>-122.4045</td><td>37.764664</td></tr><tr><td>-122.41314</td><td>37.78626</td></tr><tr><td>-122.42784</td><td>37.726635</td></tr><tr><td>-122.42443</td><td>37.745846</td></tr><tr><td>-122.41175</td><td>37.786</td></tr><tr><td>-122.43798</td><td>37.788437</td></tr><tr><td>-122.46308</td><td>37.757736</td></tr><tr><td>-122.43871</td><td>37.783596</td></tr><tr><td>-122.41845</td><td>37.75224</td></tr><tr><td>-122.38977</td><td>37.730564</td></tr><tr><td>-122.38977</td><td>37.730564</td></tr><tr><td>-122.402794</td><td>37.793335</td></tr><tr><td>-122.40432</td><td>37.718468</td></tr><tr><td>-122.46434</td><td>37.71523</td></tr><tr><td>-122.40985</td><td>37.783386</td></tr><tr><td>-122.451996</td><td>37.77409</td></tr><tr><td>-122.41161</td><td>37.78316</td></tr><tr><td>-122.51003</td><td>37.77231</td></tr><tr><td>-122.51003</td><td>37.77231</td></tr><tr><td>-122.39833</td><td>37.761814</td></tr><tr><td>-122.42209</td><td>37.750355</td></tr><tr><td>-122.42772</td><td>37.765083</td></tr><tr><td>-122.42772</td><td>37.765083</td></tr><tr><td>-122.420815</td><td>37.754486</td></tr><tr><td>-122.418434</td><td>37.75142</td></tr><tr><td>-122.414665</td><td>37.712418</td></tr><tr><td>-122.414665</td><td>37.712418</td></tr><tr><td>-122.39774</td><td>37.729935</td></tr><tr><td>-122.39774</td><td>37.729935</td></tr><tr><td>-122.45808</td><td>37.78672</td></tr><tr><td>-122.48594</td><td>37.774307</td></tr><tr><td>-122.3844</td><td>37.732506</td></tr><tr><td>-122.48745</td><td>37.757492</td></tr><tr><td>-122.47644</td><td>37.776722</td></tr><tr><td>-122.40105</td><td>37.73992</td></tr><tr><td>-122.43012</td><td>37.791286</td></tr><tr><td>-122.43012</td><td>37.791286</td></tr><tr><td>-122.40757</td><td>37.760574</td></tr><tr>< ...

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import ClusteringEvaluator

vecAssembler = VectorAssembler(inputCols=[x for x in crimes_x_y.columns], outputCol="features")
new_df = vecAssembler.transform(crimes_x_y)

from pyspark.ml.clustering import KMeans

optimum_cluster_num = 0
optimum_silhouette = 0
for i in xrange(2,3):
  kmeans = KMeans(k=i, seed=1)  # 2 clusters here
  model = kmeans.fit(new_df.select('features'))
  transformed = model.transform(new_df)
  evaluator = ClusteringEvaluator()
  silhouette = evaluator.evaluate(transformed)
  if silhouette > optimum_silhouette:
    optimum_silhouette = silhouette
    optimum_cluster_num = i
    optimum_model = model
    optimum_transformed = transformed
  print("cluster Number:"+str(i)+" Silhouette with squared euclidean distance = " + str(silhouette))
print 'optimum_cluster_num', optimum_cluster_num
optimum_transformed.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">cluster Number:2 Silhouette with squared euclidean distance = 0.690645716205
# optimum_cluster_num 2
# +-----------+---------+--------------------+----------+
#           X|        Y|            features|prediction|
# +-----------+---------+--------------------+----------+
#  -122.40062| 37.78159|[-122.40061950683...|         0|
#  -122.43613|37.775204|[-122.43612670898...|         0|
#  -122.50911| 37.75841|[-122.50910949707...|         1|
#  -122.46095|37.786896|[-122.46095275878...|         1|
#  -122.50943| 37.77985|[-122.50942993164...|         1|
#  -122.45348|37.773052|[-122.45348358154...|         1|
#   -122.4662| 37.77254|[-122.46620178222...|         1|
# -122.466736|37.753716|[-122.46673583984...|         1|
#  -122.47356|37.743145|[-122.47355651855...|         1|
# -122.403404| 37.77542|[-122.40340423583...|         0|
#  -122.49333|37.764732|[-122.49333190917...|         1|
#  -122.47337|37.754944|[-122.47337341308...|         1|
#  -122.42615| 37.73088|[-122.42614746093...|         1|
#  -122.40397| 37.78483|[-122.40396881103...|         0|
#  -122.45918|37.728397|[-122.45918273925...|         1|
# -122.417755| 37.80611|[-122.41775512695...|         0|
#  -122.42037|  37.7848|[-122.42037200927...|         0|
#  -122.39806|37.779568|[-122.39806365966...|         0|
#  -122.41474| 37.77872|[-122.41474151611...|         0|
#  -122.38849|37.789574|[-122.38848876953...|         0|
# +-----------+---------+--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
# import sys
# !{sys.executable} -m pip install bokeh
# from bokeh.io import output_file, output_notebook, show
import matplotlib.pyplot as plt
optimum_pandas = optimum_transformed.toPandas()
optimum_pandas.plot(kind="scatter", x=optimum_pandas['X'], y=optimum_pandas['Y'], alpha=0.4)
plt.show()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>my plot1</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.13.0.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#             <div class="bk-root" id="d5bd5b63-4a32-44ca-93c5-d9d59b1dca12"></div>
#
#
#
#
#         <script type="application/json" id="2f30358b-9c0a-4a7b-abbb-8d19c7db5ae3">
#           {"d828144f-36df-4129-8c69-0eb3496ce2a3":{"roots":{"references":[{"attributes":{"data_source":{"id":"d103410a-1ca4-4ead-af13-5356f4baa7b1","type":"ColumnDataSource"},"glyph":{"id":"d3eac4ad-30d0-488e-9174-2f66e835cc6b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"6fe65e19-9d87-403a-9d7a-382bd07b914b","type":"CDSView"}},"id":"de2c1a85-38f6-49eb-831f-c39e85b581a6","type":"GlyphRenderer"},{"attributes":{},"id":"45cc6e7f-d9f4-40cf-b859-0964f392e9d8","type":"UnionRenderers"},{"attributes":{"api_key":"AIzaSyCJTrqeA4SZ8S-hDkMLsCwsDepZOEZqYXs","map_options":{"id":"9a80274b-fec2-461f-a1f7-17ba623d12a6","type":"GMapOptions"},"renderers":[{"id":"de2c1a85-38f6-49eb-831f-c39e85b581a6","type":"GlyphRenderer"}],"title":{"id":"17de48a6-1411-4bc7-a9d4-1df62c6923e0","type":"Title"},"toolbar":{"id":"337da46f-b5f5-44cc-a070-64a4d80aa516","type":"Toolbar"},"x_range":{"id":"c25e7176-a244-4bff-8471-1541cd4728be","type":"Range1d"},"x_scale":{"id":"3e6f12c5-161e-4cac-b0f3-096c992ccc94","type":"LinearScale"},"y_range":{"id":"7f6de67a-b2ea-4766-a2cc-1d4ea7b4eae7","type":"Range1d"},"y_scale":{"id":"f331be6a-49e9-465c-8b42-fc31b46fa656","type":"LinearScale"}},"id":"546085d0-ab1b-4857-80e5-27871a129005","type":"GMapPlot"},{"attributes":{},"id":"2f1f7f12-8871-4924-9b6d-82574d3addbc","type":"Selection"},{"attributes":{"plot":null,"text":"Hey look! It's a scatter plot on a map!"},"id":"17de48a6-1411-4bc7-a9d4-1df62c6923e0","type":"Title"},{"attributes":{"x":{"field":"lon"},"y":{"field":"lat"}},"id":"d3eac4ad-30d0-488e-9174-2f66e835cc6b","type":"Circle"},{"attributes":{"lat":37.88,"lng":-122.23,"zoom":6},"id":"9a80274b-fec2-461f-a1f7-17ba623d12a6","type":"GMapOptions"},{"attributes":{"callback":null},"id":"7f6de67a-b2ea-4766-a2cc-1d4ea7b4eae7","type":"Range1d"},{"attributes":{"callback":null,"data":{"lat":{"__ndarray__":"...","dtype":"float32","shape":[8977]},"lon":{"__ndarray__":"...","dtype":"float32","shape":[8977]}},"selected":{"id":"2f1f7f12-8871-4924-9b6d-82574d3addbc","type":"Selection"},"selection_policy":{"id":"45cc6e7f-d9f4-40cf-b859-0964f392e9d8","type":"UnionRenderers"}},"id":"d103410a-1ca4-4ead-af13-5356f4baa7b1","type":"ColumnDataSource"},{"attributes":{},"id":"3e6f12c5-161e-4cac-b0f3-096c992ccc94","type":"LinearScale"},{"attributes":{},"id":"f331be6a-49e9-465c-8b42-fc31b46fa656","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto"},"id":"337da46f-b5f5-44cc-a070-64a4d80aa516","type":"Toolbar"},{"attributes":{"source":{"id":"d103410a-1ca4-4ead-af13-5356f4baa7b1","type":"ColumnDataSource"}},"id":"6fe65e19-9d87-403a-9d7a-382bd07b914b","type":"CDSView"},{"attributes":{"callback":null},"id":"c25e7176-a244-4bff-8471-1541cd4728be","type":"Range1d"}],"root_ids":["546085d0-ab1b-4857-80e5-27871a129005"]},"title":"Bokeh Application","version":"0.13.0"}}
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('2f30358b-9c0a-4a7b-abbb-8d19c7db5ae3').textContent;
#                   var render_items = [{"docid":"d828144f-36df-4129-8c69-0eb3496ce2a3","roots":{"546085d0-ab1b-4857-80e5-27871a129005":"d5bd5b63-4a32-44ca-93c5-d9d59b1dca12"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         embed_document(root);
#                         clearInterval(timer);
#                       }
#                       attempts++;
#                       if (attempts > 100) {
#                         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing")
#                         clearInterval(timer);
#                       }
#                     }, 10, root)
#                   }
#                 })(window);
#               });
#             };
#             if (document.readyState != "loading") fn();
#             else document.addEventListener("DOMContentLoaded", fn);
#           })();
#         </script>
#
#   </body>
#
# </html>
